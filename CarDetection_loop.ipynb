# %%
import cv2
import torch
from ultralytics import YOLO
import numpy as np
from datetime import datetime
import os
import glob
from Model.imageProcess import f_image_read, f_image_preprocessing_010, f_save_image, f_imagesingle_read, f_image_box, f_image_box_license, f_image_box_license_2
from Model.sqlProcess import f_sql_object_detection

# yolo_model = "yolo11x.pt"
# Dapatkan mapping dari ID kelas ke nama kelas

# print(f"vehicle_results : {YoloModelVehicle.names}")

def image_processing(p_yolo):

    YoloModelVehicle = YOLO(f"Yolo/{p_yolo}")
    class_names = YoloModelVehicle.names


    image_folder = 'Dataset\Vehicle'
    image_files = glob.glob(os.path.join(image_folder, '*.jpg'))

    for image in image_files:
        tanggal_start = datetime.today()
        print(f"image : {image}")

        frame = cv2.imread(image)

        vehicle_mask = np.zeros(frame.shape[:2], dtype=np.uint8)
        original_frame = frame.copy()

        # Deteksi kendaraan
        vehicle_results = YoloModelVehicle(frame)

        # print(f"vehicle_results : {vehicle_results}")
        for vehicle in vehicle_results:
            # print(f"vehicle : {vehicle.boxes}")
            for box in vehicle.boxes:
                # print(f"box : {box}")

                x1, y1, x2, y2 = map(int, box.xyxy[0].numpy())

                # print(f"box.cls[0] : {box.cls[0]}")

                class_id = int(box.cls[0])
                confidence = box.conf[0]

                if class_id in [2, 3, 5, 7] and confidence > 0.00:
                    detected_class_label = class_names[class_id]

                    # f_image_box(frame, x1, x2, y1, y2, "")

            # f_image_read(image1=original_frame, title1=f"{image} Original", image2=frame, title2="Object Box")

                    tanggal_end = datetime.today()

                    f_sql_object_detection(p_label_name=image, 
                                        p_yolo_model=p_yolo, 
                                        p_object_type=detected_class_label, 
                                        p_confidence=confidence, 
                                        p_start_dt=tanggal_start.strftime("%Y-%m-%d %H:%M:%S"), 
                                        p_end_dt=tanggal_end.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# <>:22: SyntaxWarning: invalid escape sequence '\V'
# <>:22: SyntaxWarning: invalid escape sequence '\V'
# C:\Users\susil\AppData\Local\Temp\ipykernel_46548\3952689287.py:22: SyntaxWarning: invalid escape sequence '\V'
#   image_folder = 'Dataset\Vehicle'

# %%
yolo_models = {'yolov10s.pt', 'yolov10n.pt', 'yolov10m.pt', 'yolov10b.pt', 'yolov10l.pt', 'yolov10x.pt', 'yolo11n.pt', 'yolo11s.pt', 'yolo11m.pt', 'yolo11l.pt', 'yolo11x.pt'}

for model in yolo_models:
    # print(f"model : {model}") 

    image_processing(model)
# Out:
# image : Dataset\Vehicle\fleet (1).jpg
#
# 0: 640x640 1 motorcycle, 629.7ms
# Speed: 3.5ms preprocess, 629.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (1).jpg', 'yolov10l.pt', 'motorcycle', 0.9581639766693115, '2025-07-02 00:40:24', '2025-07-02 00:40:25')
#
# image : Dataset\Vehicle\fleet (10).jpg
#
# 0: 640x640 2 persons, 1 motorcycle, 574.6ms
# Speed: 3.5ms preprocess, 574.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (10).jpg', 'yolov10l.pt', 'motorcycle', 0.7682359218597412, '2025-07-02 00:40:25', '2025-07-02 00:40:25')
#
# image : Dataset\Vehicle\fleet (100).jpg
#
# 0: 640x640 2 persons, 1 bicycle, 2 cars, 1 truck, 1 cow, 510.5ms
# Speed: 3.4ms preprocess, 510.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (100).jpg', 'yolov10l.pt', 'car', 0.8901327848434448, '2025-07-02 00:40:25', '2025-07-02 00:40:26')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (100).jpg', 'yolov10l.pt', 'truck', 0.5306407809257507, '2025-07-02 00:40:25', '2025-07-02 00:40:26')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (100).jpg', 'yolov10l.pt', 'car', 0.4829733669757843, '2025-07-02 00:40:25', '2025-07-02 00:40:26')
#
# image : Dataset\Vehicle\fleet (101).jpg
#
# 0: 640x640 1 truck, 510.0ms
# Speed: 3.2ms preprocess, 510.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (101).jpg', 'yolov10l.pt', 'truck', 0.9561882615089417, '2025-07-02 00:40:26', '2025-07-02 00:40:26')
#
# image : Dataset\Vehicle\fleet (102).jpg
#
# 0: 640x640 1 person, 1 car, 515.0ms
# Speed: 2.8ms preprocess, 515.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (102).jpg', 'yolov10l.pt', 'car', 0.7338091135025024, '2025-07-02 00:40:26', '2025-07-02 00:40:27')
#
# image : Dataset\Vehicle\fleet (103).jpg
#
# 0: 640x640 3 persons, 2 cars, 1 motorcycle, 1 truck, 549.4ms
# Speed: 3.5ms preprocess, 549.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (103).jpg', 'yolov10l.pt', 'truck', 0.8832331299781799, '2025-07-02 00:40:27', '2025-07-02 00:40:28')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (103).jpg', 'yolov10l.pt', 'car', 0.830279529094696, '2025-07-02 00:40:27', '2025-07-02 00:40:28')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (103).jpg', 'yolov10l.pt', 'car', 0.8088560700416565, '2025-07-02 00:40:27', '2025-07-02 00:40:28')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (103).jpg', 'yolov10l.pt', 'motorcycle', 0.7622146606445312, '2025-07-02 00:40:27', '2025-07-02 00:40:28')
#
# image : Dataset\Vehicle\fleet (104).jpg
#
# 0: 640x640 1 person, 2 cars, 1 truck, 534.7ms
# Speed: 3.5ms preprocess, 534.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (104).jpg', 'yolov10l.pt', 'truck', 0.9266749024391174, '2025-07-02 00:40:28', '2025-07-02 00:40:28')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (104).jpg', 'yolov10l.pt', 'car', 0.7470289468765259, '2025-07-02 00:40:28', '2025-07-02 00:40:28')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (104).jpg', 'yolov10l.pt', 'car', 0.2979743182659149, '2025-07-02 00:40:28', '2025-07-02 00:40:28')
#
# image : Dataset\Vehicle\fleet (105).jpg
#
# 0: 640x640 1 person, 1 truck, 512.0ms
# Speed: 3.2ms preprocess, 512.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (105).jpg', 'yolov10l.pt', 'truck', 0.8483642339706421, '2025-07-02 00:40:28', '2025-07-02 00:40:29')
#
# image : Dataset\Vehicle\fleet (106).jpg
#
# 0: 640x640 1 motorcycle, 527.9ms
# Speed: 3.4ms preprocess, 527.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (106).jpg', 'yolov10l.pt', 'motorcycle', 0.7670575976371765, '2025-07-02 00:40:29', '2025-07-02 00:40:29')
#
# image : Dataset\Vehicle\fleet (107).jpg
#
# 0: 640x640 3 persons, 1 car, 1 truck, 540.5ms
# Speed: 3.5ms preprocess, 540.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (107).jpg', 'yolov10l.pt', 'truck', 0.9435458183288574, '2025-07-02 00:40:29', '2025-07-02 00:40:30')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (107).jpg', 'yolov10l.pt', 'car', 0.4814193546772003, '2025-07-02 00:40:29', '2025-07-02 00:40:30')
#
# image : Dataset\Vehicle\fleet (108).jpg
#
# 0: 640x640 1 truck, 545.8ms
# Speed: 3.6ms preprocess, 545.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (108).jpg', 'yolov10l.pt', 'truck', 0.948774516582489, '2025-07-02 00:40:30', '2025-07-02 00:40:30')
#
# image : Dataset\Vehicle\fleet (109).jpg
#
# 0: 640x640 1 person, 1 car, 572.2ms
# Speed: 3.4ms preprocess, 572.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (109).jpg', 'yolov10l.pt', 'car', 0.9582983255386353, '2025-07-02 00:40:30', '2025-07-02 00:40:31')
#
# image : Dataset\Vehicle\fleet (11).jpg
#
# 0: 640x640 1 person, 1 motorcycle, 573.0ms
# Speed: 3.6ms preprocess, 573.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (11).jpg', 'yolov10l.pt', 'motorcycle', 0.8625240325927734, '2025-07-02 00:40:31', '2025-07-02 00:40:31')
#
# image : Dataset\Vehicle\fleet (110).jpg
#
# 0: 640x640 2 cars, 1 truck, 564.7ms
# Speed: 3.7ms preprocess, 564.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (110).jpg', 'yolov10l.pt', 'car', 0.4908103048801422, '2025-07-02 00:40:31', '2025-07-02 00:40:32')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (110).jpg', 'yolov10l.pt', 'truck', 0.4509560763835907, '2025-07-02 00:40:31', '2025-07-02 00:40:32')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (110).jpg', 'yolov10l.pt', 'car', 0.41358160972595215, '2025-07-02 00:40:31', '2025-07-02 00:40:32')
#
# image : Dataset\Vehicle\fleet (111).jpg
#
# 0: 640x640 1 car, 3 benchs, 563.8ms
# Speed: 4.4ms preprocess, 563.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (111).jpg', 'yolov10l.pt', 'car', 0.937439501285553, '2025-07-02 00:40:32', '2025-07-02 00:40:33')
#
# image : Dataset\Vehicle\fleet (112).jpg
#
# 0: 640x640 6 cars, 542.1ms
# Speed: 3.6ms preprocess, 542.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (112).jpg', 'yolov10l.pt', 'car', 0.9189872145652771, '2025-07-02 00:40:33', '2025-07-02 00:40:33')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (112).jpg', 'yolov10l.pt', 'car', 0.8258823156356812, '2025-07-02 00:40:33', '2025-07-02 00:40:33')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (112).jpg', 'yolov10l.pt', 'car', 0.7443181276321411, '2025-07-02 00:40:33', '2025-07-02 00:40:33')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (112).jpg', 'yolov10l.pt', 'car', 0.5286321043968201, '2025-07-02 00:40:33', '2025-07-02 00:40:33')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (112).jpg', 'yolov10l.pt', 'car', 0.50031977891922, '2025-07-02 00:40:33', '2025-07-02 00:40:33')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (112).jpg', 'yolov10l.pt', 'car', 0.39279261231422424, '2025-07-02 00:40:33', '2025-07-02 00:40:33')
#
# image : Dataset\Vehicle\fleet (113).jpg
#
# 0: 640x640 1 person, 1 car, 1 bus, 601.2ms
# Speed: 3.6ms preprocess, 601.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (113).jpg', 'yolov10l.pt', 'bus', 0.9651808738708496, '2025-07-02 00:40:33', '2025-07-02 00:40:34')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (113).jpg', 'yolov10l.pt', 'car', 0.8965756893157959, '2025-07-02 00:40:33', '2025-07-02 00:40:34')
#
# image : Dataset\Vehicle\fleet (114).jpg
#
# 0: 640x640 6 persons, 5 cars, 1 truck, 569.4ms
# Speed: 3.7ms preprocess, 569.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (114).jpg', 'yolov10l.pt', 'truck', 0.776383638381958, '2025-07-02 00:40:34', '2025-07-02 00:40:34')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (114).jpg', 'yolov10l.pt', 'car', 0.6503098011016846, '2025-07-02 00:40:34', '2025-07-02 00:40:34')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (114).jpg', 'yolov10l.pt', 'car', 0.6385857462882996, '2025-07-02 00:40:34', '2025-07-02 00:40:34')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (114).jpg', 'yolov10l.pt', 'car', 0.5955913662910461, '2025-07-02 00:40:34', '2025-07-02 00:40:34')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (114).jpg', 'yolov10l.pt', 'car', 0.5615379810333252, '2025-07-02 00:40:34', '2025-07-02 00:40:34')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (114).jpg', 'yolov10l.pt', 'car', 0.40041330456733704, '2025-07-02 00:40:34', '2025-07-02 00:40:34')
#
# image : Dataset\Vehicle\fleet (115).jpg
#
# 0: 640x640 8 persons, 1 car, 1 handbag, 552.6ms
# Speed: 3.8ms preprocess, 552.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (115).jpg', 'yolov10l.pt', 'car', 0.9018077850341797, '2025-07-02 00:40:34', '2025-07-02 00:40:35')
#
# image : Dataset\Vehicle\fleet (116).jpg
#
# 0: 640x640 3 buss, 600.3ms
# Speed: 3.8ms preprocess, 600.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (116).jpg', 'yolov10l.pt', 'bus', 0.9380420446395874, '2025-07-02 00:40:35', '2025-07-02 00:40:36')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (116).jpg', 'yolov10l.pt', 'bus', 0.6040815711021423, '2025-07-02 00:40:35', '2025-07-02 00:40:36')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (116).jpg', 'yolov10l.pt', 'bus', 0.3568727374076843, '2025-07-02 00:40:35', '2025-07-02 00:40:36')
#
# image : Dataset\Vehicle\fleet (117).jpg
#
# 0: 640x640 1 car, 642.2ms
# Speed: 5.4ms preprocess, 642.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (117).jpg', 'yolov10l.pt', 'car', 0.944012463092804, '2025-07-02 00:40:36', '2025-07-02 00:40:36')
#
# image : Dataset\Vehicle\fleet (118).jpg
#
# 0: 640x640 2 cars, 1 truck, 575.7ms
# Speed: 3.3ms preprocess, 575.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (118).jpg', 'yolov10l.pt', 'car', 0.9586862325668335, '2025-07-02 00:40:36', '2025-07-02 00:40:37')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (118).jpg', 'yolov10l.pt', 'truck', 0.3061895966529846, '2025-07-02 00:40:36', '2025-07-02 00:40:37')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (118).jpg', 'yolov10l.pt', 'car', 0.28026503324508667, '2025-07-02 00:40:36', '2025-07-02 00:40:37')
#
# image : Dataset\Vehicle\fleet (119).jpg
#
# 0: 640x640 1 truck, 640.4ms
# Speed: 3.3ms preprocess, 640.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (119).jpg', 'yolov10l.pt', 'truck', 0.9593529105186462, '2025-07-02 00:40:37', '2025-07-02 00:40:38')
#
# image : Dataset\Vehicle\fleet (12).jpg
#
# 0: 640x640 2 persons, 1 motorcycle, 609.0ms
# Speed: 6.5ms preprocess, 609.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (12).jpg', 'yolov10l.pt', 'motorcycle', 0.905955970287323, '2025-07-02 00:40:38', '2025-07-02 00:40:38')
#
# image : Dataset\Vehicle\fleet (120).jpg
#
# 0: 640x640 3 cars, 3 trucks, 547.6ms
# Speed: 4.8ms preprocess, 547.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (120).jpg', 'yolov10l.pt', 'car', 0.9209548234939575, '2025-07-02 00:40:38', '2025-07-02 00:40:39')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (120).jpg', 'yolov10l.pt', 'truck', 0.7344757914543152, '2025-07-02 00:40:38', '2025-07-02 00:40:39')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (120).jpg', 'yolov10l.pt', 'car', 0.6309038400650024, '2025-07-02 00:40:38', '2025-07-02 00:40:39')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (120).jpg', 'yolov10l.pt', 'truck', 0.4423955976963043, '2025-07-02 00:40:38', '2025-07-02 00:40:39')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (120).jpg', 'yolov10l.pt', 'car', 0.4064197540283203, '2025-07-02 00:40:38', '2025-07-02 00:40:39')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (120).jpg', 'yolov10l.pt', 'truck', 0.29508543014526367, '2025-07-02 00:40:38', '2025-07-02 00:40:39')
#
# image : Dataset\Vehicle\fleet (121).jpg
#
# 0: 640x640 2 persons, 1 car, 536.4ms
# Speed: 4.5ms preprocess, 536.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (121).jpg', 'yolov10l.pt', 'car', 0.8283048868179321, '2025-07-02 00:40:39', '2025-07-02 00:40:39')
#
# image : Dataset\Vehicle\fleet (122).jpg
#
# 0: 640x640 1 bus, 2 trucks, 600.6ms
# Speed: 3.8ms preprocess, 600.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (122).jpg', 'yolov10l.pt', 'truck', 0.9266635775566101, '2025-07-02 00:40:39', '2025-07-02 00:40:40')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (122).jpg', 'yolov10l.pt', 'bus', 0.5547792911529541, '2025-07-02 00:40:39', '2025-07-02 00:40:40')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (122).jpg', 'yolov10l.pt', 'truck', 0.3191250264644623, '2025-07-02 00:40:39', '2025-07-02 00:40:40')
#
# image : Dataset\Vehicle\fleet (123).jpg
#
# 0: 640x640 4 persons, 1 truck, 1 handbag, 688.9ms
# Speed: 5.0ms preprocess, 688.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (123).jpg', 'yolov10l.pt', 'truck', 0.9066596031188965, '2025-07-02 00:40:40', '2025-07-02 00:40:41')
#
# image : Dataset\Vehicle\fleet (124).jpg
#
# 0: 640x640 3 cars, 584.2ms
# Speed: 5.5ms preprocess, 584.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (124).jpg', 'yolov10l.pt', 'car', 0.9388275146484375, '2025-07-02 00:40:41', '2025-07-02 00:40:41')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (124).jpg', 'yolov10l.pt', 'car', 0.9301935434341431, '2025-07-02 00:40:41', '2025-07-02 00:40:41')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (124).jpg', 'yolov10l.pt', 'car', 0.8934648036956787, '2025-07-02 00:40:41', '2025-07-02 00:40:41')
#
# image : Dataset\Vehicle\fleet (125).jpg
#
# 0: 640x640 4 persons, 1 car, 610.4ms
# Speed: 4.7ms preprocess, 610.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (125).jpg', 'yolov10l.pt', 'car', 0.8067801594734192, '2025-07-02 00:40:41', '2025-07-02 00:40:42')
#
# image : Dataset\Vehicle\fleet (126).jpg
#
# 0: 640x640 2 cars, 1 truck, 563.8ms
# Speed: 4.9ms preprocess, 563.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (126).jpg', 'yolov10l.pt', 'car', 0.9263160824775696, '2025-07-02 00:40:42', '2025-07-02 00:40:42')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (126).jpg', 'yolov10l.pt', 'truck', 0.9217650890350342, '2025-07-02 00:40:42', '2025-07-02 00:40:42')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (126).jpg', 'yolov10l.pt', 'car', 0.7981181740760803, '2025-07-02 00:40:42', '2025-07-02 00:40:42')
#
# image : Dataset\Vehicle\fleet (127).jpg
#
# 0: 640x640 1 person, 1 truck, 564.3ms
# Speed: 4.3ms preprocess, 564.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (127).jpg', 'yolov10l.pt', 'truck', 0.9298146963119507, '2025-07-02 00:40:42', '2025-07-02 00:40:43')
#
# image : Dataset\Vehicle\fleet (128).jpg
#
# 0: 640x640 3 trucks, 601.0ms
# Speed: 5.0ms preprocess, 601.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (128).jpg', 'yolov10l.pt', 'truck', 0.8743188977241516, '2025-07-02 00:40:43', '2025-07-02 00:40:44')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (128).jpg', 'yolov10l.pt', 'truck', 0.7598686814308167, '2025-07-02 00:40:43', '2025-07-02 00:40:44')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (128).jpg', 'yolov10l.pt', 'truck', 0.6217119097709656, '2025-07-02 00:40:43', '2025-07-02 00:40:44')
#
# image : Dataset\Vehicle\fleet (129).jpg
#
# 0: 640x640 1 truck, 661.9ms
# Speed: 5.2ms preprocess, 661.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (129).jpg', 'yolov10l.pt', 'truck', 0.8533427715301514, '2025-07-02 00:40:44', '2025-07-02 00:40:44')
#
# image : Dataset\Vehicle\fleet (13).jpg
#
# 0: 640x640 1 person, 1 motorcycle, 564.7ms
# Speed: 4.2ms preprocess, 564.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (13).jpg', 'yolov10l.pt', 'motorcycle', 0.9163878560066223, '2025-07-02 00:40:44', '2025-07-02 00:40:45')
#
# image : Dataset\Vehicle\fleet (130).jpg
#
# 0: 640x640 2 cars, 626.7ms
# Speed: 4.0ms preprocess, 626.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (130).jpg', 'yolov10l.pt', 'car', 0.9528838396072388, '2025-07-02 00:40:45', '2025-07-02 00:40:46')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (130).jpg', 'yolov10l.pt', 'car', 0.9100813865661621, '2025-07-02 00:40:45', '2025-07-02 00:40:46')
#
# image : Dataset\Vehicle\fleet (131).jpg
#
# 0: 640x640 1 car, 3 trucks, 685.9ms
# Speed: 4.3ms preprocess, 685.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (131).jpg', 'yolov10l.pt', 'truck', 0.934198260307312, '2025-07-02 00:40:46', '2025-07-02 00:40:46')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (131).jpg', 'yolov10l.pt', 'truck', 0.9294039607048035, '2025-07-02 00:40:46', '2025-07-02 00:40:46')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (131).jpg', 'yolov10l.pt', 'truck', 0.5440443754196167, '2025-07-02 00:40:46', '2025-07-02 00:40:46')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (131).jpg', 'yolov10l.pt', 'car', 0.30124005675315857, '2025-07-02 00:40:46', '2025-07-02 00:40:46')
#
# image : Dataset\Vehicle\fleet (132).jpg
#
# 0: 640x640 1 car, 599.8ms
# Speed: 4.9ms preprocess, 599.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (132).jpg', 'yolov10l.pt', 'car', 0.9286714196205139, '2025-07-02 00:40:46', '2025-07-02 00:40:47')
#
# image : Dataset\Vehicle\fleet (133).jpg
#
# 0: 640x640 2 cars, 1 truck, 636.0ms
# Speed: 4.3ms preprocess, 636.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (133).jpg', 'yolov10l.pt', 'car', 0.7767255306243896, '2025-07-02 00:40:47', '2025-07-02 00:40:48')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (133).jpg', 'yolov10l.pt', 'car', 0.6686323285102844, '2025-07-02 00:40:47', '2025-07-02 00:40:48')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (133).jpg', 'yolov10l.pt', 'truck', 0.27269330620765686, '2025-07-02 00:40:47', '2025-07-02 00:40:48')
#
# image : Dataset\Vehicle\fleet (134).jpg
#
# 0: 640x640 1 car, 1 bus, 3 trucks, 637.9ms
# Speed: 4.1ms preprocess, 637.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (134).jpg', 'yolov10l.pt', 'truck', 0.6962608098983765, '2025-07-02 00:40:48', '2025-07-02 00:40:48')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (134).jpg', 'yolov10l.pt', 'truck', 0.4978662431240082, '2025-07-02 00:40:48', '2025-07-02 00:40:48')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (134).jpg', 'yolov10l.pt', 'bus', 0.44101545214653015, '2025-07-02 00:40:48', '2025-07-02 00:40:48')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (134).jpg', 'yolov10l.pt', 'truck', 0.38462579250335693, '2025-07-02 00:40:48', '2025-07-02 00:40:48')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (134).jpg', 'yolov10l.pt', 'car', 0.28395015001296997, '2025-07-02 00:40:48', '2025-07-02 00:40:48')
#
# image : Dataset\Vehicle\fleet (135).jpg
#
# 0: 640x640 2 cars, 1 truck, 667.9ms
# Speed: 6.0ms preprocess, 667.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (135).jpg', 'yolov10l.pt', 'car', 0.9365491271018982, '2025-07-02 00:40:48', '2025-07-02 00:40:49')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (135).jpg', 'yolov10l.pt', 'truck', 0.5880529284477234, '2025-07-02 00:40:48', '2025-07-02 00:40:49')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (135).jpg', 'yolov10l.pt', 'car', 0.33502280712127686, '2025-07-02 00:40:48', '2025-07-02 00:40:49')
#
# image : Dataset\Vehicle\fleet (136).jpg
#
# 0: 640x640 5 persons, 2 cars, 1 potted plant, 647.7ms
# Speed: 4.4ms preprocess, 647.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (136).jpg', 'yolov10l.pt', 'car', 0.9411851167678833, '2025-07-02 00:40:49', '2025-07-02 00:40:50')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (136).jpg', 'yolov10l.pt', 'car', 0.8665344715118408, '2025-07-02 00:40:49', '2025-07-02 00:40:50')
#
# image : Dataset\Vehicle\fleet (137).jpg
#
# 0: 640x640 1 car, 1 truck, 656.3ms
# Speed: 4.4ms preprocess, 656.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (137).jpg', 'yolov10l.pt', 'truck', 0.8764131665229797, '2025-07-02 00:40:50', '2025-07-02 00:40:50')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (137).jpg', 'yolov10l.pt', 'car', 0.756863534450531, '2025-07-02 00:40:50', '2025-07-02 00:40:50')
#
# image : Dataset\Vehicle\fleet (138).jpg
#
# 0: 640x640 3 cars, 621.1ms
# Speed: 4.0ms preprocess, 621.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (138).jpg', 'yolov10l.pt', 'car', 0.9405350685119629, '2025-07-02 00:40:50', '2025-07-02 00:40:51')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (138).jpg', 'yolov10l.pt', 'car', 0.8902149200439453, '2025-07-02 00:40:50', '2025-07-02 00:40:51')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (138).jpg', 'yolov10l.pt', 'car', 0.79723060131073, '2025-07-02 00:40:50', '2025-07-02 00:40:51')
#
# image : Dataset\Vehicle\fleet (139).jpg
#
# 0: 640x640 4 persons, 5 cars, 632.2ms
# Speed: 6.3ms preprocess, 632.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (139).jpg', 'yolov10l.pt', 'car', 0.9231645464897156, '2025-07-02 00:40:51', '2025-07-02 00:40:52')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (139).jpg', 'yolov10l.pt', 'car', 0.7576042413711548, '2025-07-02 00:40:51', '2025-07-02 00:40:52')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (139).jpg', 'yolov10l.pt', 'car', 0.6644909381866455, '2025-07-02 00:40:51', '2025-07-02 00:40:52')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (139).jpg', 'yolov10l.pt', 'car', 0.4665280878543854, '2025-07-02 00:40:51', '2025-07-02 00:40:52')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (139).jpg', 'yolov10l.pt', 'car', 0.4008128046989441, '2025-07-02 00:40:51', '2025-07-02 00:40:52')
#
# image : Dataset\Vehicle\fleet (14).jpg
#
# 0: 640x640 1 person, 1 motorcycle, 666.5ms
# Speed: 3.2ms preprocess, 666.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (14).jpg', 'yolov10l.pt', 'motorcycle', 0.9159412980079651, '2025-07-02 00:40:52', '2025-07-02 00:40:52')
#
# image : Dataset\Vehicle\fleet (140).jpg
#
# 0: 640x640 2 cars, 2 trucks, 636.5ms
# Speed: 4.3ms preprocess, 636.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (140).jpg', 'yolov10l.pt', 'truck', 0.44312968850135803, '2025-07-02 00:40:52', '2025-07-02 00:40:53')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (140).jpg', 'yolov10l.pt', 'car', 0.40260547399520874, '2025-07-02 00:40:52', '2025-07-02 00:40:53')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (140).jpg', 'yolov10l.pt', 'car', 0.347000390291214, '2025-07-02 00:40:52', '2025-07-02 00:40:53')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (140).jpg', 'yolov10l.pt', 'truck', 0.26139533519744873, '2025-07-02 00:40:52', '2025-07-02 00:40:53')
#
# image : Dataset\Vehicle\fleet (141).jpg
#
# 0: 640x640 1 car, 1 truck, 602.9ms
# Speed: 3.0ms preprocess, 602.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (141).jpg', 'yolov10l.pt', 'car', 0.5315854549407959, '2025-07-02 00:40:53', '2025-07-02 00:40:53')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (141).jpg', 'yolov10l.pt', 'truck', 0.4436300992965698, '2025-07-02 00:40:53', '2025-07-02 00:40:53')
#
# image : Dataset\Vehicle\fleet (142).jpg
#
# 0: 448x640 8 persons, 1 car, 1 truck, 1 handbag, 455.0ms
# Speed: 2.0ms preprocess, 455.0ms inference, 0.3ms postprocess per image at shape (1, 3, 448, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (142).jpg', 'yolov10l.pt', 'car', 0.5713743567466736, '2025-07-02 00:40:53', '2025-07-02 00:40:54')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (142).jpg', 'yolov10l.pt', 'truck', 0.4399961829185486, '2025-07-02 00:40:53', '2025-07-02 00:40:54')
#
# image : Dataset\Vehicle\fleet (143).jpg
#
# 0: 416x640 1 car, 413.3ms
# Speed: 2.1ms preprocess, 413.3ms inference, 0.3ms postprocess per image at shape (1, 3, 416, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (143).jpg', 'yolov10l.pt', 'car', 0.9645949006080627, '2025-07-02 00:40:54', '2025-07-02 00:40:54')
#
# image : Dataset\Vehicle\fleet (144).jpg
#
# 0: 480x640 7 cars, 502.4ms
# Speed: 3.7ms preprocess, 502.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (144).jpg', 'yolov10l.pt', 'car', 0.9595650434494019, '2025-07-02 00:40:54', '2025-07-02 00:40:55')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (144).jpg', 'yolov10l.pt', 'car', 0.8932394981384277, '2025-07-02 00:40:54', '2025-07-02 00:40:55')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (144).jpg', 'yolov10l.pt', 'car', 0.787380576133728, '2025-07-02 00:40:54', '2025-07-02 00:40:55')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (144).jpg', 'yolov10l.pt', 'car', 0.7530201077461243, '2025-07-02 00:40:54', '2025-07-02 00:40:55')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (144).jpg', 'yolov10l.pt', 'car', 0.5020822286605835, '2025-07-02 00:40:54', '2025-07-02 00:40:55')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (144).jpg', 'yolov10l.pt', 'car', 0.3303312659263611, '2025-07-02 00:40:54', '2025-07-02 00:40:55')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (144).jpg', 'yolov10l.pt', 'car', 0.2860182225704193, '2025-07-02 00:40:54', '2025-07-02 00:40:55')
#
# image : Dataset\Vehicle\fleet (145).jpg
#
# 0: 480x640 1 car, 478.7ms
# Speed: 2.5ms preprocess, 478.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (145).jpg', 'yolov10l.pt', 'car', 0.967882513999939, '2025-07-02 00:40:55', '2025-07-02 00:40:55')
#
# image : Dataset\Vehicle\fleet (146).jpg
#
# 0: 448x640 1 person, 5 cars, 433.7ms
# Speed: 2.5ms preprocess, 433.7ms inference, 0.3ms postprocess per image at shape (1, 3, 448, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (146).jpg', 'yolov10l.pt', 'car', 0.9161360263824463, '2025-07-02 00:40:55', '2025-07-02 00:40:56')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (146).jpg', 'yolov10l.pt', 'car', 0.9080214500427246, '2025-07-02 00:40:55', '2025-07-02 00:40:56')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (146).jpg', 'yolov10l.pt', 'car', 0.9000593423843384, '2025-07-02 00:40:55', '2025-07-02 00:40:56')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (146).jpg', 'yolov10l.pt', 'car', 0.5241339206695557, '2025-07-02 00:40:55', '2025-07-02 00:40:56')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (146).jpg', 'yolov10l.pt', 'car', 0.2935771942138672, '2025-07-02 00:40:55', '2025-07-02 00:40:56')
#
# image : Dataset\Vehicle\fleet (147).jpg
#
# 0: 448x640 1 car, 422.4ms
# Speed: 2.1ms preprocess, 422.4ms inference, 0.3ms postprocess per image at shape (1, 3, 448, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (147).jpg', 'yolov10l.pt', 'car', 0.9633268713951111, '2025-07-02 00:40:56', '2025-07-02 00:40:56')
#
# image : Dataset\Vehicle\fleet (148).jpg
#
# 0: 480x640 4 cars, 1 truck, 458.6ms
# Speed: 2.7ms preprocess, 458.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (148).jpg', 'yolov10l.pt', 'car', 0.9580444097518921, '2025-07-02 00:40:56', '2025-07-02 00:40:57')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (148).jpg', 'yolov10l.pt', 'car', 0.9036415815353394, '2025-07-02 00:40:56', '2025-07-02 00:40:57')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (148).jpg', 'yolov10l.pt', 'car', 0.35587039589881897, '2025-07-02 00:40:56', '2025-07-02 00:40:57')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (148).jpg', 'yolov10l.pt', 'car', 0.29792970418930054, '2025-07-02 00:40:56', '2025-07-02 00:40:57')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (148).jpg', 'yolov10l.pt', 'truck', 0.26913759112358093, '2025-07-02 00:40:56', '2025-07-02 00:40:57')
#
# image : Dataset\Vehicle\fleet (149).jpg
#
# 0: 480x640 4 cars, 1 train, 470.5ms
# Speed: 2.3ms preprocess, 470.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (149).jpg', 'yolov10l.pt', 'car', 0.954789400100708, '2025-07-02 00:40:57', '2025-07-02 00:40:57')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (149).jpg', 'yolov10l.pt', 'car', 0.9353187084197998, '2025-07-02 00:40:57', '2025-07-02 00:40:57')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (149).jpg', 'yolov10l.pt', 'car', 0.6529803276062012, '2025-07-02 00:40:57', '2025-07-02 00:40:57')
#
# ...
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (89).jpg', 'yolo11l.pt', 'car', 0.6774193048477173, '2025-07-02 01:03:33', '2025-07-02 01:03:33')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (89).jpg', 'yolo11l.pt', 'car', 0.5915238857269287, '2025-07-02 01:03:33', '2025-07-02 01:03:33')
#
# image : Dataset\Vehicle\fleet (9).jpg
#
# 0: 640x640 6 motorcycles, 488.9ms
# Speed: 3.9ms preprocess, 488.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (9).jpg', 'yolo11l.pt', 'motorcycle', 0.9464104175567627, '2025-07-02 01:03:33', '2025-07-02 01:03:34')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (9).jpg', 'yolo11l.pt', 'motorcycle', 0.535251796245575, '2025-07-02 01:03:33', '2025-07-02 01:03:34')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (9).jpg', 'yolo11l.pt', 'motorcycle', 0.5293408632278442, '2025-07-02 01:03:33', '2025-07-02 01:03:34')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (9).jpg', 'yolo11l.pt', 'motorcycle', 0.3848247528076172, '2025-07-02 01:03:33', '2025-07-02 01:03:34')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (9).jpg', 'yolo11l.pt', 'motorcycle', 0.27719053626060486, '2025-07-02 01:03:33', '2025-07-02 01:03:34')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (9).jpg', 'yolo11l.pt', 'motorcycle', 0.27522069215774536, '2025-07-02 01:03:33', '2025-07-02 01:03:34')
#
# image : Dataset\Vehicle\fleet (90).jpg
#
# 0: 640x640 2 persons, 3 cars, 2 trucks, 2 stop signs, 442.7ms
# Speed: 3.9ms preprocess, 442.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (90).jpg', 'yolo11l.pt', 'truck', 0.9336236119270325, '2025-07-02 01:03:34', '2025-07-02 01:03:34')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (90).jpg', 'yolo11l.pt', 'car', 0.8893324732780457, '2025-07-02 01:03:34', '2025-07-02 01:03:34')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (90).jpg', 'yolo11l.pt', 'car', 0.7497808337211609, '2025-07-02 01:03:34', '2025-07-02 01:03:34')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (90).jpg', 'yolo11l.pt', 'car', 0.6848747730255127, '2025-07-02 01:03:34', '2025-07-02 01:03:34')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (90).jpg', 'yolo11l.pt', 'truck', 0.647994339466095, '2025-07-02 01:03:34', '2025-07-02 01:03:34')
#
# image : Dataset\Vehicle\fleet (91).jpg
#
# 0: 640x640 1 truck, 8 potted plants, 544.4ms
# Speed: 3.7ms preprocess, 544.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (91).jpg', 'yolo11l.pt', 'truck', 0.8844510912895203, '2025-07-02 01:03:34', '2025-07-02 01:03:35')
#
# image : Dataset\Vehicle\fleet (92).jpg
#
# 0: 640x640 1 person, 2 cars, 1 motorcycle, 2 trucks, 447.7ms
# Speed: 3.6ms preprocess, 447.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (92).jpg', 'yolo11l.pt', 'car', 0.8775531053543091, '2025-07-02 01:03:35', '2025-07-02 01:03:35')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (92).jpg', 'yolo11l.pt', 'motorcycle', 0.7288153767585754, '2025-07-02 01:03:35', '2025-07-02 01:03:35')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (92).jpg', 'yolo11l.pt', 'truck', 0.5247906446456909, '2025-07-02 01:03:35', '2025-07-02 01:03:35')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (92).jpg', 'yolo11l.pt', 'car', 0.42242199182510376, '2025-07-02 01:03:35', '2025-07-02 01:03:35')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (92).jpg', 'yolo11l.pt', 'truck', 0.40921077132225037, '2025-07-02 01:03:35', '2025-07-02 01:03:35')
#
# image : Dataset\Vehicle\fleet (93).jpg
#
# 0: 640x640 1 truck, 512.6ms
# Speed: 3.5ms preprocess, 512.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (93).jpg', 'yolo11l.pt', 'truck', 0.7620211243629456, '2025-07-02 01:03:35', '2025-07-02 01:03:36')
#
# image : Dataset\Vehicle\fleet (94).jpg
#
# 0: 640x640 7 persons, 1 bicycle, 1 car, 2 trucks, 465.2ms
# Speed: 3.6ms preprocess, 465.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (94).jpg', 'yolo11l.pt', 'truck', 0.904507040977478, '2025-07-02 01:03:36', '2025-07-02 01:03:36')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (94).jpg', 'yolo11l.pt', 'truck', 0.6747388243675232, '2025-07-02 01:03:36', '2025-07-02 01:03:36')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (94).jpg', 'yolo11l.pt', 'car', 0.6388912796974182, '2025-07-02 01:03:36', '2025-07-02 01:03:36')
#
# image : Dataset\Vehicle\fleet (95).jpg
#
# 0: 640x640 9 persons, 1 bus, 501.6ms
# Speed: 4.3ms preprocess, 501.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (95).jpg', 'yolo11l.pt', 'bus', 0.89789879322052, '2025-07-02 01:03:36', '2025-07-02 01:03:37')
#
# image : Dataset\Vehicle\fleet (96).jpg
#
# 0: 640x640 2 persons, 3 cars, 461.2ms
# Speed: 3.5ms preprocess, 461.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (96).jpg', 'yolo11l.pt', 'car', 0.9202425479888916, '2025-07-02 01:03:37', '2025-07-02 01:03:37')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (96).jpg', 'yolo11l.pt', 'car', 0.7237846851348877, '2025-07-02 01:03:37', '2025-07-02 01:03:37')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (96).jpg', 'yolo11l.pt', 'car', 0.5493737459182739, '2025-07-02 01:03:37', '2025-07-02 01:03:37')
#
# image : Dataset\Vehicle\fleet (97).jpg
#
# 0: 640x640 2 persons, 3 cars, 513.3ms
# Speed: 4.4ms preprocess, 513.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (97).jpg', 'yolo11l.pt', 'car', 0.9202425479888916, '2025-07-02 01:03:37', '2025-07-02 01:03:38')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (97).jpg', 'yolo11l.pt', 'car', 0.7237846851348877, '2025-07-02 01:03:37', '2025-07-02 01:03:38')
#
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (97).jpg', 'yolo11l.pt', 'car', 0.5493737459182739, '2025-07-02 01:03:37', '2025-07-02 01:03:38')
#
# image : Dataset\Vehicle\fleet (98).jpg
#
# 0: 640x640 1 car, 506.6ms
# Speed: 3.2ms preprocess, 506.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (98).jpg', 'yolo11l.pt', 'car', 0.8088403940200806, '2025-07-02 01:03:38', '2025-07-02 01:03:38')
#
# image : Dataset\Vehicle\fleet (99).jpg
#
# 0: 640x640 1 truck, 473.4ms
# Speed: 3.4ms preprocess, 473.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# sql : insert into t_object_detection (label_name, yolo_model, object_type, confidence, process_start_dt, process_end_dt) values
#                 ('Dataset\Vehicle\fleet (99).jpg', 'yolo11l.pt', 'truck', 0.9426121115684509, '2025-07-02 01:03:38', '2025-07-02 01:03:39')
#
# image : Dataset\Vehicle\people (1).jpg
#
# 0: 448x640 1 person, 328.8ms
# Speed: 1.9ms preprocess, 328.8ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# image : Dataset\Vehicle\people (10).jpg
#
# 0: 640x512 1 person, 1 baseball bat, 420.5ms
# Speed: 3.1ms preprocess, 420.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
# image : Dataset\Vehicle\people (11).jpg
#
# 0: 448x640 1 person, 1 chair, 349.9ms
# Speed: 2.5ms preprocess, 349.9ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# image : Dataset\Vehicle\people (12).jpg
#
# 0: 640x640 1 person, 470.0ms
# Speed: 4.4ms preprocess, 470.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# image : Dataset\Vehicle\people (13).jpg
#
# 0: 640x576 2 persons, 1 cell phone, 496.1ms
# Speed: 3.4ms preprocess, 496.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 576)
# image : Dataset\Vehicle\people (14).jpg
#
# 0: 640x544 1 person, 460.3ms
# Speed: 3.5ms preprocess, 460.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 544)
# image : Dataset\Vehicle\people (15).jpg
#
# 0: 512x640 1 person, 1 book, 454.8ms
# Speed: 2.4ms preprocess, 454.8ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
# image : Dataset\Vehicle\people (16).jpg
#
# 0: 480x640 1 person, 361.0ms
# Speed: 2.8ms preprocess, 361.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# image : Dataset\Vehicle\people (17).jpg
#
# 0: 512x640 3 persons, 1 book, 401.6ms
# Speed: 2.2ms preprocess, 401.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
# image : Dataset\Vehicle\people (18).jpg
#
# 0: 640x416 1 person, 1 backpack, 1 handbag, 348.0ms
# Speed: 2.0ms preprocess, 348.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)
# image : Dataset\Vehicle\people (19).jpg
#
# 0: 448x640 1 person, 1 book, 321.4ms
# Speed: 2.0ms preprocess, 321.4ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 640)
# image : Dataset\Vehicle\people (2).jpg
#
# 0: 448x640 4 persons, 1 boat, 1 backpack, 1 umbrella, 1 cup, 324.4ms
# Speed: 2.3ms preprocess, 324.4ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# image : Dataset\Vehicle\people (20).jpg
#
# 0: 448x640 9 persons, 311.6ms
# Speed: 2.4ms preprocess, 311.6ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
# image : Dataset\Vehicle\people (21).jpg
#
# 0: 576x640 5 persons, 429.5ms
# Speed: 3.3ms preprocess, 429.5ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
# image : Dataset\Vehicle\people (22).jpg
#
# 0: 448x640 2 persons, 315.4ms
# Speed: 1.9ms preprocess, 315.4ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# image : Dataset\Vehicle\people (23).jpg
#
# 0: 416x640 3 persons, 1 bottle, 6 chairs, 356.3ms
# Speed: 1.6ms preprocess, 356.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# image : Dataset\Vehicle\people (24).jpg
#
# 0: 448x640 8 persons, 316.7ms
# Speed: 2.4ms preprocess, 316.7ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# image : Dataset\Vehicle\people (25).jpg
#
# 0: 448x640 2 persons, 1 suitcase, 1 cell phone, 316.1ms
# Speed: 1.8ms preprocess, 316.1ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# image : Dataset\Vehicle\people (26).jpg
#
# 0: 608x640 3 persons, 500.4ms
# Speed: 3.3ms preprocess, 500.4ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# image : Dataset\Vehicle\people (27).jpg
#
# 0: 416x640 5 persons, 2 backpacks, 300.8ms
# Speed: 2.0ms preprocess, 300.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# image : Dataset\Vehicle\people (28).jpg
#
# 0: 640x640 1 person, 526.6ms
# Speed: 3.9ms preprocess, 526.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# image : Dataset\Vehicle\people (3).jpg
#
# 0: 448x640 1 person, 1 tie, 317.0ms
# Speed: 1.9ms preprocess, 317.0ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# image : Dataset\Vehicle\people (4).jpg
#
# 0: 288x640 2 persons, 1 kite, 247.9ms
# Speed: 1.5ms preprocess, 247.9ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 640)
# image : Dataset\Vehicle\people (5).jpg
#
# 0: 384x640 1 person, 332.2ms
# Speed: 1.7ms preprocess, 332.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# image : Dataset\Vehicle\people (6).jpg
#
# 0: 640x480 1 person, 1 refrigerator, 363.6ms
# Speed: 2.3ms preprocess, 363.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# image : Dataset\Vehicle\people (7).jpg
#
# 0: 480x640 4 persons, 1 backpack, 1 tie, 1 cell phone, 335.8ms
# Speed: 2.3ms preprocess, 335.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# image : Dataset\Vehicle\people (8).jpg
#
# 0: 448x640 10 persons, 1 potted plant, 2 dining tables, 314.3ms
# Speed: 1.6ms preprocess, 314.3ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# image : Dataset\Vehicle\people (9).jpg
#
# 0: 448x640 1 person, 1 cell phone, 1 book, 373.6ms
# Speed: 1.9ms preprocess, 373.6ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
