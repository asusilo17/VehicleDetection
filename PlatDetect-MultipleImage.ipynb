# %%
import cv2
import torch
import os
from paddleocr import PaddleOCR
from ultralytics import YOLO
import numpy as np
from datetime import datetime
from Model.imageProcess import f_image_read, f_image_preprocessing_010, f_save_image, f_imagesingle_read, f_image_box, f_image_box_license, f_image_box_license_2
from Model.generalProcess import f_remove_special_char
from Model.ocrProcess import f_ocr_process
from Model.sqlProcess import f_sql_savePlateIdentification

# Inisialisasi OCR dan Model YOLO
ocr = PaddleOCR(use_angle_cls=True, lang='en')
YoloModelVehicle = YOLO("Yolo/yolov10m.pt")
YoloModelLicenseNumber = YOLO("Yolo/best.pt")

# Folder berisi gambar
folder_path = "DataTraining/PlatNomor"
image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

# Loop setiap gambar
for img_name in image_files:
    img_path = os.path.join(folder_path, img_name)

    frame = cv2.imread(img_path)
    if frame is None:
        print(f"Failed to read {img_path}")
        continue

    print(f"Processing {img_name}...")

    original_frame = frame.copy()

    license_plate_results = YoloModelLicenseNumber(original_frame)

    for result in license_plate_results:
        for lp_box in result.boxes:
            lx1, ly1, lx2, ly2 = map(int, lp_box.xyxy[0].numpy())
            lp_conf = lp_box.conf[0]

            frame = f_image_box(frame, lx1, lx2, ly1, ly2, "")

            # f_image_read(image1=original_frame, title1="original", image2=frame_2, title2="plat")

            cv2.imwrite(filename=f"{folder_path}/Result/{img_name}-ok.jpeg",
                                        img=frame)
# Out:
# [2025/07/07 23:48:03] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, use_gcu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\susil/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\susil/.paddleocr/whl\\rec\\en\\en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25, rec_char_dict_path='d:\\Mine\\UNPAM\\THESIS\\VehicleDetection\\.venv\\Lib\\site-packages\\paddleocr\\ppocr\\utils\\en_dict.txt', use_space_char=True, vis_font_path='./doc/fonts/simfang.ttf', drop_score=0.5, e2e_algorithm='PGNet', e2e_model_dir=None, e2e_limit_side_len=768, e2e_limit_type='max', e2e_pgnet_score_thresh=0.5, e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_pgnet_valid_set='totaltext', e2e_pgnet_mode='fast', use_angle_cls=True, cls_model_dir='C:\\Users\\susil/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_image_shape='3, 48, 192', label_list=['0', '180'], cls_batch_num=6, cls_thresh=0.9, enable_mkldnn=False, cpu_threads=10, use_pdserving=False, warmup=False, sr_model_dir=None, sr_image_shape='3, 32, 128', sr_batch_num=1, draw_img_save_dir='./inference_results', save_crop_res=False, crop_res_save_dir='./output', use_mp=False, total_process_num=1, process_id=0, benchmark=False, save_log_path='./log_output/', show_log=True, use_onnx=False, onnx_providers=False, onnx_sess_options=False, return_word_box=False, output='./output', table_max_len=488, table_algorithm='TableAttn', table_model_dir=None, merge_no_span_structure=True, table_char_dict_path=None, formula_algorithm='LaTeXOCR', formula_model_dir=None, formula_char_dict_path=None, formula_batch_num=1, layout_model_dir=None, layout_dict_path=None, layout_score_threshold=0.5, layout_nms_threshold=0.5, kie_algorithm='LayoutXLM', ser_model_dir=None, re_model_dir=None, use_visual_backbone=True, ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ocr_order_method=None, mode='structure', image_orientation=False, layout=True, table=True, formula=False, ocr=True, recovery=False, recovery_to_markdown=False, use_pdf2docx_api=False, invert=False, binarize=False, alphacolor=(255, 255, 255), lang='en', det=True, rec=True, type='ocr', savefile=False, ocr_version='PP-OCRv4', structure_version='PP-StructureV2')
# Processing Plat (1).jpg...
#
# 0: 640x640 1 license, 110.6ms
# Speed: 4.9ms preprocess, 110.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (100).jpg...
#
# 0: 640x640 1 license, 115.9ms
# Speed: 3.1ms preprocess, 115.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (101).jpg...
#
# 0: 640x640 1 license, 88.9ms
# Speed: 3.3ms preprocess, 88.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (102).jpg...
#
# 0: 640x640 (no detections), 93.6ms
# Speed: 3.4ms preprocess, 93.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (103).jpg...
#
# 0: 640x640 1 license, 94.7ms
# Speed: 4.2ms preprocess, 94.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (104).jpg...
#
# 0: 640x640 1 license, 103.9ms
# Speed: 3.7ms preprocess, 103.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (105).jpg...
#
# 0: 640x640 1 license, 118.0ms
# Speed: 3.7ms preprocess, 118.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (106).jpg...
#
# 0: 640x640 (no detections), 92.5ms
# Speed: 4.8ms preprocess, 92.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (107).jpg...
#
# 0: 640x640 1 license, 97.4ms
# Speed: 2.9ms preprocess, 97.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (108).jpg...
#
# 0: 640x640 1 license, 123.0ms
# Speed: 5.9ms preprocess, 123.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (109).jpg...
#
# 0: 640x640 1 license, 103.0ms
# Speed: 4.5ms preprocess, 103.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (110).jpg...
#
# 0: 640x640 1 license, 84.1ms
# Speed: 4.9ms preprocess, 84.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (111).jpg...
#
# 0: 640x640 1 license, 91.3ms
# Speed: 3.0ms preprocess, 91.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (112).jpg...
#
# 0: 640x640 1 license, 135.4ms
# Speed: 4.2ms preprocess, 135.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (113).jpg...
#
# 0: 640x640 1 license, 227.4ms
# Speed: 4.6ms preprocess, 227.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (114).jpg...
#
# 0: 640x640 1 license, 236.1ms
# Speed: 5.7ms preprocess, 236.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (115).jpg...
#
# 0: 640x640 1 license, 114.6ms
# Speed: 4.4ms preprocess, 114.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (116).jpg...
#
# 0: 640x640 (no detections), 86.4ms
# Speed: 3.3ms preprocess, 86.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (117).jpg...
#
# 0: 640x640 1 license, 86.6ms
# Speed: 3.4ms preprocess, 86.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (118).jpg...
#
# 0: 640x640 1 license, 89.0ms
# Speed: 4.2ms preprocess, 89.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (119).jpg...
#
# 0: 640x640 (no detections), 85.2ms
# Speed: 4.2ms preprocess, 85.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (120).jpg...
#
# 0: 640x640 1 license, 87.0ms
# Speed: 3.2ms preprocess, 87.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (121).jpg...
#
# 0: 640x640 1 license, 89.8ms
# Speed: 3.3ms preprocess, 89.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (122).jpg...
#
# 0: 640x640 1 license, 83.2ms
# Speed: 3.5ms preprocess, 83.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (123).jpg...
#
# 0: 640x640 1 license, 83.5ms
# Speed: 3.6ms preprocess, 83.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (124).jpg...
#
# 0: 640x640 1 license, 80.2ms
# Speed: 3.0ms preprocess, 80.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (125).jpg...
#
# 0: 640x640 1 license, 79.8ms
# Speed: 3.8ms preprocess, 79.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (126).jpg...
#
# 0: 640x640 1 license, 82.0ms
# Speed: 3.4ms preprocess, 82.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (127).jpg...
#
# 0: 640x640 1 license, 88.5ms
# Speed: 4.3ms preprocess, 88.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (128).jpg...
#
# 0: 640x640 1 license, 82.6ms
# Speed: 2.8ms preprocess, 82.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (129).jpg...
#
# 0: 640x640 1 license, 80.9ms
# Speed: 3.6ms preprocess, 80.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (130).jpg...
#
# 0: 640x640 1 license, 120.1ms
# Speed: 3.1ms preprocess, 120.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (131).jpg...
#
# 0: 640x640 1 license, 290.8ms
# Speed: 4.3ms preprocess, 290.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (132).jpg...
#
# 0: 640x640 1 license, 128.1ms
# Speed: 6.4ms preprocess, 128.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (133).jpg...
#
# 0: 640x640 1 license, 110.4ms
# Speed: 3.0ms preprocess, 110.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (134).jpg...
#
# 0: 640x640 1 license, 246.1ms
# Speed: 4.5ms preprocess, 246.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (135).jpg...
#
# 0: 640x640 (no detections), 226.3ms
# Speed: 4.2ms preprocess, 226.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (136).jpg...
#
# 0: 640x640 (no detections), 109.6ms
# Speed: 5.6ms preprocess, 109.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (137).jpg...
#
# 0: 640x640 1 license, 144.0ms
# Speed: 3.2ms preprocess, 144.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (138).jpg...
#
# 0: 640x640 1 license, 82.5ms
# Speed: 2.8ms preprocess, 82.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (139).jpg...
#
# 0: 640x640 (no detections), 115.9ms
# Speed: 13.3ms preprocess, 115.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (140).jpg...
#
# 0: 640x640 (no detections), 86.1ms
# Speed: 3.5ms preprocess, 86.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (141).jpg...
#
# 0: 640x640 1 license, 82.5ms
# Speed: 3.2ms preprocess, 82.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (142).jpg...
#
# 0: 640x640 (no detections), 76.5ms
# Speed: 4.1ms preprocess, 76.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (143).jpg...
#
# 0: 640x640 1 license, 82.6ms
# Speed: 2.9ms preprocess, 82.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (144).jpg...
#
# 0: 640x640 1 license, 91.5ms
# Speed: 3.4ms preprocess, 91.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (145).jpg...
#
# 0: 640x640 2 licenses, 159.3ms
# Speed: 5.6ms preprocess, 159.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (146).jpg...
#
# 0: 640x640 (no detections), 127.0ms
# Speed: 4.3ms preprocess, 127.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (147).jpg...
#
# 0: 640x640 (no detections), 121.9ms
# Speed: 4.0ms preprocess, 121.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (148).jpg...
#
# 0: 640x640 (no detections), 172.2ms
# Speed: 3.5ms preprocess, 172.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (149).jpg...
#
# 0: 640x640 1 license, 127.2ms
# Speed: 3.9ms preprocess, 127.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (150).jpg...
#
# 0: 640x640 (no detections), 179.6ms
# Speed: 4.0ms preprocess, 179.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (151).jpg...
#
# 0: 640x640 1 license, 158.7ms
# Speed: 8.8ms preprocess, 158.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (152).jpg...
#
# 0: 640x640 (no detections), 120.8ms
# Speed: 4.2ms preprocess, 120.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (153).jpg...
#
# 0: 640x640 1 license, 87.9ms
# Speed: 6.1ms preprocess, 87.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (154).jpg...
#
# 0: 640x640 (no detections), 133.8ms
# Speed: 3.4ms preprocess, 133.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (155).jpg...
#
# 0: 640x640 (no detections), 93.4ms
# Speed: 3.8ms preprocess, 93.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (156).jpg...
#
# 0: 640x640 1 license, 81.0ms
# Speed: 2.9ms preprocess, 81.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (157).jpg...
#
# 0: 640x640 1 license, 84.4ms
# Speed: 3.6ms preprocess, 84.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (158).jpg...
#
# 0: 640x640 1 license, 102.2ms
# Speed: 4.2ms preprocess, 102.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (159).jpg...
#
# 0: 640x640 (no detections), 78.8ms
# Speed: 2.9ms preprocess, 78.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (160).jpg...
#
# 0: 640x640 1 license, 89.9ms
# Speed: 3.6ms preprocess, 89.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (161).jpg...
#
# 0: 640x640 (no detections), 80.0ms
# Speed: 3.4ms preprocess, 80.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (162).jpg...
#
# 0: 640x640 1 license, 95.7ms
# Speed: 3.2ms preprocess, 95.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (163).jpg...
#
# 0: 640x640 1 license, 92.4ms
# Speed: 4.1ms preprocess, 92.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (164).jpg...
#
# 0: 640x640 1 license, 77.6ms
# Speed: 3.9ms preprocess, 77.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (165).jpg...
#
# 0: 640x640 (no detections), 88.4ms
# Speed: 2.9ms preprocess, 88.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (166).jpg...
#
# 0: 640x640 (no detections), 139.3ms
# Speed: 3.4ms preprocess, 139.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (167).jpg...
#
# 0: 640x640 1 license, 120.2ms
# Speed: 7.3ms preprocess, 120.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (168).jpg...
#
# 0: 640x640 1 license, 82.5ms
# Speed: 4.3ms preprocess, 82.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (169).jpg...
#
# 0: 640x640 1 license, 97.7ms
# Speed: 3.6ms preprocess, 97.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (170).jpg...
#
# 0: 640x640 (no detections), 83.8ms
# Speed: 3.7ms preprocess, 83.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (59).jpg...
#
# 0: 640x640 1 license, 77.2ms
# Speed: 3.1ms preprocess, 77.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (60).jpg...
#
# 0: 640x640 (no detections), 97.4ms
# Speed: 3.4ms preprocess, 97.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (61).jpg...
#
# 0: 640x640 1 license, 113.3ms
# Speed: 3.9ms preprocess, 113.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (62).jpg...
#
# 0: 640x640 1 license, 121.1ms
# Speed: 4.2ms preprocess, 121.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (63).jpg...
#
# 0: 640x640 1 license, 228.5ms
# Speed: 4.0ms preprocess, 228.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (64).jpg...
#
# 0: 640x640 1 license, 79.9ms
# Speed: 3.7ms preprocess, 79.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (65).jpg...
#
# 0: 640x640 (no detections), 79.1ms
# Speed: 3.3ms preprocess, 79.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (66).jpg...
#
# 0: 640x640 1 license, 96.8ms
# Speed: 3.9ms preprocess, 96.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (67).jpg...
#
# 0: 640x640 2 licenses, 130.7ms
# Speed: 3.2ms preprocess, 130.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (68).jpg...
#
# 0: 640x640 (no detections), 93.7ms
# Speed: 4.5ms preprocess, 93.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (69).jpg...
#
# 0: 640x640 1 license, 93.8ms
# Speed: 3.2ms preprocess, 93.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (70).jpg...
#
# 0: 640x640 1 license, 98.4ms
# Speed: 3.1ms preprocess, 98.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (71).jpg...
#
# 0: 640x640 2 licenses, 93.4ms
# Speed: 5.3ms preprocess, 93.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (72).jpg...
#
# 0: 640x640 1 license, 84.1ms
# Speed: 4.6ms preprocess, 84.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (73).jpg...
#
# 0: 640x640 (no detections), 82.7ms
# Speed: 3.4ms preprocess, 82.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (74).jpg...
#
# 0: 640x640 1 license, 88.2ms
# Speed: 3.4ms preprocess, 88.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (75).jpg...
#
# 0: 640x640 1 license, 87.3ms
# Speed: 4.2ms preprocess, 87.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (76).jpg...
#
# 0: 640x640 1 license, 158.1ms
# Speed: 5.8ms preprocess, 158.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (77).jpg...
#
# 0: 640x640 1 license, 105.6ms
# Speed: 4.5ms preprocess, 105.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (78).jpg...
#
# 0: 640x640 2 licenses, 112.6ms
# Speed: 4.1ms preprocess, 112.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (79).jpg...
#
# 0: 640x640 1 license, 121.1ms
# Speed: 2.9ms preprocess, 121.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (80).jpg...
#
# 0: 640x640 2 licenses, 125.8ms
# Speed: 3.5ms preprocess, 125.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (81).jpg...
#
# 0: 640x640 1 license, 140.3ms
# Speed: 4.0ms preprocess, 140.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (82).jpg...
#
# 0: 640x640 1 license, 127.8ms
# Speed: 4.0ms preprocess, 127.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (83).jpg...
#
# 0: 640x640 2 licenses, 124.1ms
# Speed: 4.2ms preprocess, 124.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (84).jpg...
#
# 0: 640x640 1 license, 170.7ms
# Speed: 4.0ms preprocess, 170.7ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (85).jpg...
#
# 0: 640x640 1 license, 148.0ms
# Speed: 9.0ms preprocess, 148.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (86).jpg...
#
# 0: 640x640 1 license, 93.7ms
# Speed: 3.7ms preprocess, 93.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (87).jpg...
#
# 0: 640x640 1 license, 102.2ms
# Speed: 5.0ms preprocess, 102.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (88).jpg...
#
# 0: 640x640 1 license, 123.8ms
# Speed: 4.4ms preprocess, 123.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (89).jpg...
#
# 0: 640x640 1 license, 128.8ms
# Speed: 4.2ms preprocess, 128.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (90).jpg...
#
# 0: 640x640 1 license, 113.3ms
# Speed: 5.8ms preprocess, 113.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (91).jpg...
#
# 0: 640x640 1 license, 97.2ms
# Speed: 4.8ms preprocess, 97.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (92).jpg...
#
# 0: 640x640 1 license, 87.9ms
# Speed: 3.4ms preprocess, 87.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (93).jpg...
#
# 0: 640x640 1 license, 87.0ms
# Speed: 4.1ms preprocess, 87.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (94).jpg...
#
# 0: 640x640 1 license, 93.4ms
# Speed: 3.7ms preprocess, 93.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (95).jpg...
#
# 0: 640x640 1 license, 130.4ms
# Speed: 4.3ms preprocess, 130.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (96).jpg...
#
# 0: 640x640 1 license, 137.2ms
# Speed: 4.6ms preprocess, 137.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (97).jpg...
#
# 0: 640x640 1 license, 106.3ms
# Speed: 4.2ms preprocess, 106.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (98).jpg...
#
# 0: 640x640 1 license, 103.4ms
# Speed: 4.7ms preprocess, 103.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
# Processing Plat (99).jpg...
#
# 0: 640x640 1 license, 98.7ms
# Speed: 5.2ms preprocess, 98.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
